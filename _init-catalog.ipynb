# %%
# %sql
CREATE DATABASE IF NOT EXISTS crp_arb_dev.bronze
MANAGED LOCATION 'abfss://crp-arb-cnt@sadlsdev.dfs.core.windows.net/bronze';

CREATE DATABASE IF NOT EXISTS crp_arb_dev.silver
MANAGED LOCATION 'abfss://crp-arb-cnt@sadlsdev.dfs.core.windows.net/silver';

CREATE DATABASE IF NOT EXISTS crp_arb_dev.gold
MANAGED LOCATION 'abfss://crp-arb-cnt@sadlsdev.dfs.core.windows.net/gold';

CREATE DATABASE IF NOT EXISTS crp_arb_dev._checkpoints
MANAGED LOCATION 'abfss://crp-arb-cnt@sadlsdev.dfs.core.windows.net/_checkpoints';
